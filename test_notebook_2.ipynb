# %% [markdown]
# <a href="https://colab.research.google.com/github/fayez94/Fortune_500/blob/main/test_notebook_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as  pd
df = pd.read_csv("/content/Top_Companies_of_USA.csv")
display(df)
# Out:
#      Rank               Country                                  Industry  \
# 0       1               Walmart                     General Merchandisers
# 1       2                Amazon           Internet Services and Retailing
# 2       3                 Apple               Computers, Office Equipment
# 3       4    UnitedHealth Group   Health Care: Insurance and Managed Care
# 4       5    Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# ..    ...                   ...                                       ...
# 495   496      Monster Beverage                                 Beverages
# 496   497    Intuitive Surgical            Medical Products and Equipment
# 497   498  Super Micro Computer               Computers, Office Equipment
# 498   499            Concentrix           Information Technology Services
# 499   500             O-I Glass                     Packaging, Containers
#
#             City       State    Zip                Website  Employees  \
# ...
